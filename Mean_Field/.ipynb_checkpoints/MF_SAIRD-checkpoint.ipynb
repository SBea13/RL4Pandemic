# %% [markdown]
# # SAIRD
# Applying the NEAT tecnique to the SAIRD model explained below

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class GSAIRD():
    
    def __init__(self, R0=2, alpha=0.07, gamma=0.3, eta=0.2, N=60e+6, A=1, 
                 report=False):
        self.N = N               # Total number of people
        self.A0 = A              # Initial asyntomatics
        self.R0 = R0
        self.A = A               # Asyntomatic
        self.I = 0               # Infective
        self.R = 0               # Recovered
        self.D = 0               # Dead
        self.S = self.N - self.I # Susceptible
        self.int_ter = 152e+3    # Places in intensive terapy in hospitals
        
        self.beta0 = R0*(gamma+eta) # Initial susc->asy rate
        self.alpha0 = alpha       # Initial asy->inf rate 1/incubation
        self.gamma0 = gamma       # Initial recovering rate
        self.eta0 = eta           # Initial inf->dead rate
        self.beta = R0*(gamma+eta)# Susc->asy rate
        self.alpha = alpha        # Asy->Inf rate
        self.gamma = gamma        # Inf->Rec rate
        self.eta = eta      # Inf->Dead rate
        self.chi = 0.05           # Knowing rate. The "system" knows only the worst
                                  # cases, 5%. Can be augmented with tests.
        self.old_chi = 0.05
        
        self.res_founds = 2       # Invest in research
        self.t_borders = 0        # Days from start of closure of borders
        self.t_quarantine = 0     # Days from start quarantine
        self.rew = 0              # Reward of the process
        self.num_ac = 11          # Number of possible actions from the system
        self.ac_report = np.zeros( self.num_ac )
        
        self.k = self.I*self.chi/self.N  # Known infected.
        self.O = [self.k, self.res_founds] # Observations known to the network
        self.report = report      # If true write on file the actions
        self.status = 'Running'   # Status of the system
        if self.report:
            self.writer = open('reporter.txt', 'w')
            self.evolution = [[alpha], [self.beta], [gamma], [eta], [self.chi] ]
            self.Ss = []
            self.As = []
            self.Is = []
            self.Rs = []
            self.Ds = []
        
    def reset(self):
        self.__init__(N=self.N, A=self.A0, R0=self.R0, gamma=self.gamma0,
                     alpha=self.alpha0, eta=self.eta0, report=self.report)
                
    def SAIRD(self):
        dS = -self.beta*self.S*self.A/self.N
        dA = self.beta*self.S*self.A/self.N  - self.alpha*self.A -self.gamma*self.A/4
        dI = self.alpha*self.A - self.gamma*self.I/2 - self.eta*self.I
        dR = self.gamma*self.I*3/4 + self.gamma*self.A/4
        dD = self.eta*self.I
        
        self.S += dS
        self.A += dA
        self.I += dI
        self.R += dR
        self.D += dD
        
        
    def action_sel(self, ac):
        ac = ac/ac.sum()# Normalization of the probabilities
        sorting = np.argsort(ac) # Map between sorted ac and original ac
        ac = np.sort(ac)  # Sorted ac
        u = np.random.rand()              # Random number to select the action 
        sel = np.searchsorted(ac, u)-1    # Selection of the action
        index = sorting[sel]              # Map to action number 
        return index
    
    def ac0(self):
        """ Do nothing """
        self.ac_report[0] += 1
        
    def ac1(self):
        """ Use minor protection, like mask and washing hands. No "rage" from people. """
        if self.ac_report[1] == 0:
            self.beta *= 0.9              # Arbitrary, to be determine from data
        self.ac_report[1] += 1
        
    def ac2(self):
        """ Close country frontiers. Small rage from people. """
        if self.ac_report[2] == 0:
            self.beta *= 0.8
            self.ac_report[2] += 1
        
    def ac3(self):
        """ Remove block on frontiers. """
        if self.ac_report[2] == 1:
            self.beta /= 0.8
            self.ac_report[2] -= 1
            self.t_borders = 0
        self.ac_report[3] += 1
            
    def ac4(self):
        """ Quarantine. Medium rage from people. """
        if self.ac_report[4] == 0:
            self.beta *= 0.5
            self.ac_report[4] += 1
            
    def ac5(self):
        """ Remove quarantine. """
        if self.ac_report[4] == 1:
            self.beta /= 0.5
            self.ac_report[4] -= 1       
            self.t_quarantine = 0
        self.ac_report[5] += 1
        
    def ac6(self):
        """ Selective quarantine. """
        if self.ac_report[6] == 0:
            self.beta *= (1-self.chi)
            self.old_chi = self.chi
            self.ac_report[6] += 1
            
    def ac7(self):
        """ Remove selective quarantine. """
        if self.ac_report[6] == 1:
            self.ac_report[6] -= 1
            self.beta /= (1-self.old_chi)
        self.ac_report[7] += 1
        
    def ac8(self):
        """ Invest in research. """
        self.res_founds += 1
        self.ac_report[8] += 1
        
    def ac9(self):
        """ Spend founds in tests. """
        if self.res_founds >= 1:
            self.res_founds -= 1
            self.chi /= 0.9       # Increase number of people visible from the system
        self.ac_report[9] += 1
        
    def ac10(self):
        """ Spend founds in better cure. """
        if self.res_founds >= 1:
            self.res_founds -= 1
            self.gamma /= 0.9    # Increase number of recovered people
            self.eta *= 0.9      # Decrease the number of dead people
        self.ac_report[10] += 1
        
#    def ac11(self):
#        """ For greater good. """
#        self.I -= chi*self.I    # Kill all the known infects
#        self.rew -= 5
        
    def _reward(self):
        if self.S != 0:
            if self.ac_report[2] > 0: # Rage from closing the country
                self.rew -= (1.1 - np.exp(-0.005*self.t_borders) )
                self.t_borders += 1
            if self.ac_report[4] > 0: # Rage from quarantine
                self.rew -= (1.2 - np.exp(-0.01*self.t_quarantine) )
                self.t_quarantine += 1
            if self.I*0.05 >= self.int_ter: # hospital breakdown
                self.rew -= 10
            self.rew += 1 - (self.I+self.A+self.D)/self.N
            
            
    def _update(self, index):
        if   index == 0:  self.ac0()
        elif index == 1:  self.ac1() 
        elif index == 2:  self.ac2() 
        elif index == 3:  self.ac3() 
        elif index == 4:  self.ac4() 
        elif index == 5:  self.ac5() 
        elif index == 6:  self.ac6() 
        elif index == 7:  self.ac7() 
        elif index == 8:  self.ac8() 
        elif index == 9:  self.ac9() 
        elif index == 10: self.ac10() 
        #elif index == 11: self.ac11() 
        
    def _upd_obs(self):
        self.k = self.S*self.chi/self.N  # Known infected.
        self.O = [self.k, self.res_founds] # Observations known to the network
    
    def _report(self, index, num):
        self.ac_des = ['00) Do nothing. \n', 
                       '01) Use minor protection, like mask and washing hands. \n',
                       '02) Close country borders. \n',
                       '03) Remove block on borders. \n',
                       '04) Imposing quarantine. \n',
                       '05) Remove quarantine. \n',
                       '06) Impose quarantine only on known infected. \n',
                       '07) Remove selective quarantine. \n',
                       '08) Invest in research. \n',
                       '09) Spend research founds in test. \n',
                       '10) Spend research founds in searching for a cure. \n'#,
                      # '11) Kill all known infects. \n'
                      ]
        if num%3==0:
            self.writer.write(self.ac_des[index])
        self.evolution[0].append( self.alpha )
        self.evolution[1].append( self.beta )
        self.evolution[2].append( self.gamma )
        self.evolution[3].append( self.eta )
        self.evolution[4].append( self.chi )
        self.Ss.append( self.S/self.N)
        self.As.append( self.A/self.N)
        self.Is.append( self.I/self.N)
        self.Rs.append( self.R/self.N)
        self.Ds.append( self.D/self.N)
        
    def close_rep(self):
        if self.report:
            self.writer.close()
    
    def step(self, actions):
        index = self.action_sel(actions)
        self._update(index)
        for _ in range(3):
            self.SAIRD()
            self._reward()
            self._upd_obs()
            if self.report: self._report(index, _)
        if (self.A < 1 and self.I <1): self.status = 'Finished'

# %%
from SaveLoadNet import load_object, save_object
from visualize import draw_net
import neat
import os

config_file = os.path.join('.', './../Config/config_gestional.txt')
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     config_file)

# %%
env = GSAIRD(R0=2.5)

def eval_genomes(genomes, config):
    networks = [neat.nn.RecurrentNetwork.create(genome, config) for (genomeid, genome) in genomes]    
    obs = env.O
    rew = []
    
    env.reset()
    for net in networks:
        temp_rew = []
        for _ in range(10):
            for i in range(500):
                actions = np.array( net.activate(obs) )
                env.step(actions)
                obs = env.O
                if env.status == 'Finished': break    
            temp_rew.append( env.rew )
            env.reset()
        temp_rew = np.array(temp_rew)
        rew.append( temp_rew.mean() )
        
    for i, (genomeid, genome) in enumerate(genomes):
            genome.fitness = rew[i]


    env.reset()

# %%
p = neat.Population(config)
p.add_reporter(neat.StdOutReporter(True))
stats = neat.StatisticsReporter()
p.add_reporter(stats)
#p.add_reporter(neat.Checkpointer(5))
N_iter = 50
singol = p.run(eval_genomes, N_iter)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: -39.41175 stdev: 32.73584
# Best fitness: 2.01806 - size: (12, 24) - species 2 - id 223
# Average adjusted fitness: 0.752
# Mean genetic distance 2.412, standard deviation 0.309
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    90    -38.5    0.766     0
#      2    0   160    -43.5    0.738     0
# Total extinctions: 0
# Generation time: 10.561 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -33.42311 stdev: 29.87425
# Best fitness: -1.40222 - size: (12, 14) - species 2 - id 314
# Average adjusted fitness: 0.813
# Mean genetic distance 2.327, standard deviation 0.322
# Population of 250 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    83    -33.6    0.812     0
#      2    1   166    -33.3    0.814     0
#      3    0     1       --       --     0
# Total extinctions: 0
# Generation time: 9.499 sec (10.030 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -30.52255 stdev: 30.05113
# Best fitness: -0.83724 - size: (13, 13) - species 2 - id 717
# Average adjusted fitness: 0.850
# Mean genetic distance 2.565, standard deviation 0.594
# Population of 251 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   100    -35.9    0.756     1
#      2    2    65    -28.0    0.811     0
#      3    1    86     -3.2    0.983     0
# Total extinctions: 0
# Generation time: 11.080 sec (10.380 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -27.36545 stdev: 31.60914
# Best fitness: 8.16646 - size: (13, 16) - species 3 - id 880
# Average adjusted fitness: 0.794
# Mean genetic distance 2.717, standard deviation 0.576
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   126    -29.4    0.781     0
#      2    3    36    -26.5    0.798     0
#      3    2    84    -25.6    0.804     1
#      4    0     4       --       --     0
# Total extinctions: 0
# Generation time: 8.714 sec (9.963 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -20.88053 stdev: 26.20990
# Best fitness: 14.30478 - size: (11, 8) - species 3 - id 1215
# Average adjusted fitness: 0.714
# Mean genetic distance 2.807, standard deviation 0.545
# Population of 251 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4
average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: -9.95251 stdev: 17.66293
# Best fitness: 2.37732 - size: (13, 9) - species 8 - id 6020
# Average adjusted fitness: 0.889
# Mean genetic distance 2.775, standard deviation 0.471
# Population of 251 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24    30     -5.8    0.928     0
#      2   24    65     -9.0    0.900     1
#      4   21    58     -7.6    0.912     7
#      5   13    20     -8.2    0.907     1
#      6   13    17    -18.8    0.814    12
#      7    5    19     -8.5    0.904     3
#      8    3    42    -14.1    0.855     2
# Total extinctions: 0
# Generation time: 7.580 sec (8.643 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: -8.09148 stdev: 9.49767
# Best fitness: 0.58947 - size: (11, 7) - species 7 - id 6375
# Average adjusted fitness: 0.885
# Mean genetic distance 2.797, standard deviation 0.463
# Population of 251 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25    17     -5.5    0.918     0
#      2   25    56    -10.3    0.854     2
#      4   22    36     -6.2    0.908     0
#      5   14    40     -5.8    0.914     2
#      6   14    32    -11.0    0.844    13
#      7    6    35     -8.0    0.885     4
#      8    4    35     -9.0    0.871     0
# Total extinctions: 0
# Generation time: 8.126 sec (8.678 average)
#
#  ****** Running generation 26 ******
# /Users/Marco/opt/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:66: RuntimeWarning: invalid value encountered in true_divide
# Population's average fitness: -9.06088 stdev: 13.61609
# Best fitness: 1.07589 - size: (12, 9) - species 4 - id 6654
# Average adjusted fitness: 0.901
# Mean genetic distance 2.735, standard deviation 0.454
# Population of 252 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26    25     -8.0    0.914     1
#      2   26    74     -6.3    0.930     0
#      4   23    25     -6.4    0.930     1
#      5   15    36     -5.6    0.937     3
#      6   15    34    -18.9    0.811    14
#      7    7    33     -7.9    0.915     5
#      8    5    25    -12.8    0.868     1
# Total extinctions: 0
# Generation time: 8.799 sec (8.765 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: -7.66317 stdev: 11.58120
# Best fitness: 1.00996 - size: (12, 4) - species 6 - id 6758
# Average adjusted fitness: 0.918
# Mean genetic distance 2.757, standard deviation 0.446
# Population of 252 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27    15     -6.3    0.933     2
#      2   27    50     -6.2    0.934     0
#      4   24    37     -4.9    0.945     0
#      5   16    90     -5.1    0.944     0
#      6   16    17    -11.7    0.882    15
#      7    8    23    -10.7    0.891     6
#      8    6    13    -10.4    0.894     2
#      9    0     2       --       --     0
#     10    0     5       --       --     0
# Total extinctions: 0
# Generation time: 7.298 sec (8.684 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: -9.26603 stdev: 16.79433
# Best fitness: 1.14361 - size: (16, 14) - species 1 - id 7110
# Average adjusted fitness: 0.903
# Mean genetic distance 2.851, standard deviation 0.485
# Population of 252 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28    26     -5.7    0.935     3
#      2   28    35     -7.8    0.915     1
#      4   25    22     -5.4    0.937     1
#      5   17    25    -11.2    0.882     1
#      6   17    49    -14.5    0.851    16
#      7    9    33     -7.2    0.920     7
#      8    7    17    -14.2    0.854     3
#      9    1    13     -7.6    0.916     0
#     10    1    32     -7.8    0.914     0
# Total extinctions: 0
# Generation time: 7.635 sec (8.381 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: -8.78822 stdev: 13.06053
# Best fitness: 1.13795 - size: (13, 9) - species 7 - id 7428
# Average adjusted fitness: 0.912
# Mean genetic distance 2.839, standard deviation 0.495
# Population of 250 members in 9 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29    34     -9.2    0.908     4
#      2   29    13     -7.1    0.927     2
#      4   26    13     -5.3    0.943     2
#      5   18    11    -10.5    0.896     2
#      6   18   104    -10.0    0.901    17
#      7   10    21     -8.4    0.915     8
#      8    8    28    -10.6    0.895     4
#      9    2    19     -9.1    0.909     1
#     10    2     7     -8.8    0.911     1
# Total extinctions: 0
# Generation time: 7.597 sec (8.148 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: -8.62243 stdev: 11.02640
# Best fitness: 2.75812 - size: (13, 7) - species 6 - id 7713
# Average adjusted fitness: 0.852
# Mean genetic distance 2.851, standard deviation 0.491
# Population of 249 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30    43     -6.6    0.881     5
#      2   30    15     -5.9    0.891     0
#      4   27    34     -6.4    0.884     3
#      5   19     6    -15.1    0.774     3
#      6   19    61     -8.0    0.864     0
#      7   11    52     -9.4    0.847     9
#      8    9    17    -11.4    0.822     5
#      9    3     8    -10.6    0.831     2
#     10    3    10     -7.1    0.876     0
#     11    0     3       --       --     0
# Total extinctions: 0
# Generation time: 7.673 sec (8.058 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: -12.48158 stdev: 19.66593
# Best fitness: -0.07399 - size: (11, 5) - species 4 - id 7982
# Average adjusted fitness: 0.888
# Mean genetic distance 2.833, standard deviation 0.525
# Population of 249 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31    23     -7.0    0.933     6
#      2   31    21    -13.6    0.870     1
#      4   28    26     -8.1    0.923     4
#      5   20    48     -4.6    0.956     0
#      6   20    26    -12.5    0.881     1
#      7   12    57    -19.5    0.813    10
#      8   10    11    -13.3    0.873     6
#      9    4    14    -19.4    0.814     3
#     10    4    15    -12.6    0.880     1
#     11    1     8     -6.9    0.934     0
# Total extinctions: 0
# Generation time: 10.265 sec (8.152 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: -10.81899 stdev: 17.30666
# Best fitness: 3.33767 - size: (15, 6) - species 6 - id 8160
# Average adjusted fitness: 0.888
# Mean genetic distance 2.808, standard deviation 0.518
# Population of 248 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32    21     -6.9    0.910     7
#      2   32    39     -4.5    0.931     0
#      4   29    15     -5.9    0.919     5
#      5   21    64    -11.4    0.870     1
#      6   21    11    -10.0    0.882     2
#      7   13     9    -18.2    0.809    11
#      8   11    29     -8.6    0.895     0
#      9    5    20     -9.3    0.889     4
#     10    5    22     -9.4    0.888     2
#     11    2    18     -9.4    0.887     1
# Total extinctions: 0
# Generation time: 8.701 sec (8.135 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: -9.39410 stdev: 13.43429
# Best fitness: 1.77271 - size: (11, 3) - species 6 - id 8421
# Average adjusted fitness: 0.900
# Mean genetic distance 2.860, standard deviation 0.519
# Population of 248 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33     5    -13.2    0.861     8
#      2   33    33     -7.4    0.916     1
#      4   30    13     -6.3    0.926     6
#      5   22    25     -9.1    0.899     2
#      6   22     4     -5.2    0.936     0
#      7   14    70     -5.2    0.935     0
#      8   12    31    -12.9    0.864     1
#      9    6    24    -10.8    0.884     5
#     10    6    26     -7.5    0.914     3
#     11    3    17    -12.6    0.867     2
# Total extinctions: 0
# Generation time: 8.819 sec (8.250 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: -12.44276 stdev: 20.46955
# Best fitness: 0.49579 - size: (11, 4) - species 2 - id 8513
# Average adjusted fitness: 0.889
# Mean genetic distance 2.833, standard deviation 0.529
# Population of 248 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34     6     -8.8    0.917     9
#      2   34    30     -5.1    0.950     2
#      4   31    35     -5.7    0.944     7
#      5   23    40    -17.5    0.839     3
#      6   23    17     -6.5    0.937     1
#      7   15    25    -14.2    0.868     1
#      8   13    23    -11.8    0.890     2
#      9    7    29     -8.1    0.923     6
#     10    7    27     -8.4    0.921     4
#     11    4    16    -33.1    0.699     3
# Total extinctions: 0
# Generation time: 9.295 sec (8.421 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: -9.46846 stdev: 11.30319
# Best fitness: 2.45713 - size: (13, 9) - species 4 - id 8811
# Average adjusted fitness: 0.874
# Mean genetic distance 2.759, standard deviation 0.498
# Population of 248 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35    38     -7.6    0.896    10
#      2   35    52     -5.7    0.915     3
#      4   32    22     -7.5    0.897     8
#      5   24     3    -11.7    0.853     4
#      6   24    34    -14.3    0.826     2
#      7   16    18    -13.4    0.836     2
#      8   14     9     -6.2    0.910     0
#      9    8    30     -7.8    0.894     7
#     10    8    16     -8.5    0.886     5
#     11    5    26    -14.1    0.828     4
# Total extinctions: 0
# Generation time: 9.265 sec (8.535 average)
#
#  ****** Running generation 36 ******
# Population's average fitness: -8.38272 stdev: 9.47684
# Best fitness: 1.95644 - size: (12, 7) - species 1 - id 9081
# Average adjusted fitness: 0.863
# Mean genetic distance 2.744, standard deviation 0.512
# Population of 250 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36    28     -6.7    0.890    11
#      2   36    11     -8.6    0.867     4
#      4   33    27     -6.3    0.896     9
#      5   25    15    -11.4    0.831     5
#      6   25    85     -7.1    0.886     3
#      7   17    29    -16.5    0.767     3
#      8   15    14     -8.0    0.875     1
#      9    9    19     -6.7    0.891     0
#     10    9    11     -6.5    0.893     0
#     11    6    11    -11.2    0.834     5
# Total extinctions: 0
# Generation time: 11.153 sec (8.770 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: -8.01087 stdev: 11.54320
# Best fitness: 0.97351 - size: (14, 9) - species 2 - id 9339
# Average adjusted fitness: 0.920
# Mean genetic distance 2.821, standard deviation 0.517
# Population of 249 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37    29     -6.6    0.927    12
#      2   37    26     -3.8    0.954     0
#      4   34    19     -7.0    0.924    10
#      5   26    24     -7.5    0.919     6
#      6   26    57     -8.5    0.909     4
#      7   18    16    -13.3    0.864     4
#      8   16    17     -7.4    0.920     2
#      9   10    34     -5.8    0.935     0
#     10   10    19     -6.4    0.930     0
#     11    7     8     -7.4    0.920     6
# Total extinctions: 0
# Generation time: 9.364 sec (8.977 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: -8.66819 stdev: 13.47520
# Best fitness: 0.40179 - size: (13, 7) - species 4 - id 9519
# Average adjusted fitness: 0.915
# Mean genetic distance 2.765, standard deviation 0.481
# Population of 248 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38    23     -5.7    0.945    13
#      2   38    18     -8.1    0.924     1
#      4   35    16     -4.4    0.957     0
#      5   27    19    -17.7    0.838     7
#      6   27    10     -8.1    0.924     5
#      7   19     6    -19.5    0.822     5
#      8   17    80     -6.5    0.938     3
#      9   11    30     -5.2    0.950     0
#     10   11    19     -8.0    0.925     1
#     11    8    27     -8.3    0.922     7
# Total extinctions: 0
# Generation time: 11.176 sec (9.331 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: -9.29779 stdev: 13.95504
# Best fitness: 0.90593 - size: (13, 7) - species 4 - id 9985
# Average adjusted fitness: 0.913
# Mean genetic distance 2.790, standard deviation 0.486
# Population of 250 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39    30     -9.0    0.912    14
#      2   39    20     -6.3    0.936     2
#      4   36     9     -4.8    0.950     1
#      5   28    16    -16.9    0.841     8
#      6   28    66     -8.4    0.917     6
#      7   20    28     -4.8    0.949     0
#      8   18    13     -8.8    0.913     4
#      9   12    28    -13.8    0.869     1
#     10   12    17     -9.0    0.912     2
#     11    9    23     -6.8    0.931     0
# Total extinctions: 0
# Generation time: 11.296 sec (9.701 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: -8.68114 stdev: 13.58868
# Best fitness: -0.29938 - size: (13, 6) - species 2 - id 10121
# Average adjusted fitness: 0.920
# Mean genetic distance 2.780, standard deviation 0.475
# Population of 250 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40    32     -5.8    0.950    15
#      2   40    11     -4.8    0.960     3
#      4   37    11     -6.4    0.945     2
#      5   29    20    -30.9    0.724     9
#      6   29     8     -9.0    0.922     7
#      7   21     7     -6.3    0.946     1
#      8   19    19     -7.2    0.937     5
#      9   13    10     -7.7    0.934     2
#     10   13    91     -7.4    0.936     3
#     11   10    41     -6.3    0.946     0
# Total extinctions: 0
# Generation time: 10.406 sec (9.974 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: -5.80493 stdev: 3.61296
# Best fitness: 1.62994 - size: (12, 6) - species 10 - id 10305
# Average adjusted fitness: 0.740
# Mean genetic distance 2.743, standard deviation 0.520
# Population of 251 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41    12     -4.9    0.781     0
#      2   41    28     -5.2    0.771     4
#      4   38    12     -5.7    0.753     3
#      5   30    21     -6.6    0.724    10
#      6   30    19     -4.8    0.783     0
#      7   22    60     -8.7    0.652     2
#      8   20    15     -7.5    0.695     6
#      9   14    10     -5.9    0.748     3
#     10   14    26     -5.1    0.773     0
#     11   11    48     -6.8    0.718     1
# Total extinctions: 0
# Generation time: 9.899 sec (9.937 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: -7.98477 stdev: 11.00181
# Best fitness: 1.52774 - size: (14, 7) - species 10 - id 10575
# Average adjusted fitness: 0.918
# Mean genetic distance 2.855, standard deviation 0.516
# Population of 249 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42     7     -8.2    0.913     1
#      2   42    35     -9.2    0.905     5
#      4   39    17     -5.8    0.935     4
#      5   31    21    -12.3    0.878    11
#      6   31    18     -6.5    0.929     1
#      7   23     4     -6.4    0.929     3
#      8   21    13     -6.7    0.927     7
#      9   15    10     -6.3    0.931     4
#     10   15    87     -6.1    0.933     1
#     11   12    37    -10.2    0.896     2
# Total extinctions: 0
# Generation time: 8.640 sec (9.931 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: -7.16188 stdev: 5.96491
# Best fitness: -0.17658 - size: (13, 4) - species 5 - id 10756
# Average adjusted fitness: 0.889
# Mean genetic distance 2.832, standard deviation 0.532
# Population of 249 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43     6     -6.5    0.902     2
#      2   43    29     -8.6    0.869     6
#      4   40    22     -7.1    0.892     5
#      5   32    18     -8.0    0.879    12
#      6   32    15     -6.3    0.905     2
#      7   24    19     -8.5    0.871     4
#      8   22    24     -6.4    0.903     8
#      9   16    44     -8.0    0.878     5
#     10   16    40     -6.5    0.902     2
#     11   13    32     -7.3    0.890     3
# Total extinctions: 0
# Generation time: 11.144 sec (10.164 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: -6.98879 stdev: 5.68450
# Best fitness: 1.89948 - size: (14, 9) - species 9 - id 11024
# Average adjusted fitness: 0.858
# Mean genetic distance 2.810, standard deviation 0.514
# Population of 251 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44    13     -5.3    0.887     3
#      2   44    16     -4.6    0.897     7
#      4   41    33     -5.7    0.879     6
#      5   33    17    -10.9    0.798    13
#      6   33    37     -7.5    0.851     3
#      7   25    13     -9.3    0.822     5
#      8   23    25     -7.5    0.851     9
#      9   17    16     -7.3    0.855     6
#     10   17    23     -6.5    0.867     3
#     11   14    58     -6.2    0.871     0
# Total extinctions: 0
# Generation time: 9.166 sec (10.151 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: -7.34704 stdev: 8.93747
# Best fitness: 1.43917 - size: (15, 8) - species 11 - id 11334
# Average adjusted fitness: 0.922
# Mean genetic distance 2.860, standard deviation 0.497
# Population of 249 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   45    23     -6.1    0.933     4
#      2   45    18     -5.3    0.941     8
#      4   42    40     -6.1    0.933     7
#      5   34    24    -14.9    0.855    14
#      6   34    40     -7.3    0.922     4
#      7   26    25     -5.7    0.937     6
#      8   24    23     -8.6    0.911    10
#      9   18     6     -7.2    0.923     7
#     10   18     8     -5.1    0.942     4
#     11   15    42     -7.4    0.921     1
# Total extinctions: 0
# Generation time: 8.266 sec (10.051 average)
#
#  ****** Running generation 46 ******
# Population's average fitness: -7.61904 stdev: 10.85745
# Best fitness: 1.22353 - size: (17, 10) - species 9 - id 11558
# Average adjusted fitness: 0.914
# Mean genetic distance 2.858, standard deviation 0.540
# Population of 250 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   46    12     -5.2    0.943     5
#      2   46    19     -5.3    0.942     9
#      4   43    35     -5.6    0.939     8
#      5   35    18    -17.0    0.838    15
#      6   35    33     -5.5    0.940     5
#      7   27     6     -7.1    0.926     7
#      8   25    15     -7.3    0.925    11
#      9   19    78     -5.4    0.942     8
#     10   19    20    -19.0    0.820     5
#     11   16    14     -7.1    0.926     2
# Total extinctions: 0
# Generation time: 8.517 sec (9.787 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: -7.39889 stdev: 9.88676
# Best fitness: 0.70554 - size: (11, 4) - species 4 - id 11754
# Average adjusted fitness: 0.925
# Mean genetic distance 2.788, standard deviation 0.520
# Population of 250 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   47    28     -5.2    0.946     6
#      2   47    15     -4.9    0.948    10
#      4   44    23     -6.1    0.938     9
#      5   36    17    -15.5    0.851    16
#      6   36    10     -5.2    0.946     6
#      7   28    16    -10.4    0.898     8
#      8   26    17     -6.6    0.933    12
#      9   20    47     -8.5    0.916     9
#     10   20    61     -6.0    0.938     6
#     11   17    16     -6.4    0.934     3
# Total extinctions: 0
# Generation time: 7.860 sec (9.637 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: -6.75704 stdev: 6.09157
# Best fitness: -0.30152 - size: (13, 3) - species 8 - id 12017
# Average adjusted fitness: 0.925
# Mean genetic distance 2.734, standard deviation 0.502
# Population of 251 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   48    12     -5.6    0.939     7
#      2   48     8     -6.0    0.934    11
#      4   45    47     -6.5    0.929    10
#      5   37   100     -9.3    0.897    17
#      6   37    11     -5.9    0.936     7
#      7   29     9     -7.3    0.920     9
#      8   27    16     -6.8    0.925    13
#      9   21     7     -8.5    0.906    10
#     10   21    17     -5.6    0.939     7
#     11   18    24     -6.5    0.929     4
# Total extinctions: 0
# Generation time: 8.929 sec (9.412 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: -8.14091 stdev: 11.77854
# Best fitness: 1.24415 - size: (14, 6) - species 5 - id 12401
# Average adjusted fitness: 0.923
# Mean genetic distance 2.674, standard deviation 0.522
# Population of 250 members in 10 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   49    96     -6.2    0.930     8
#      2   49    23     -7.3    0.920    12
#      4   46    17     -7.1    0.922    11
#      5   38    23    -10.2    0.893    18
#      6   38    13     -4.2    0.949     0
#      7   30    18     -6.2    0.931    10
#      8   28    21     -7.9    0.915    14
#      9   22     7     -7.0    0.923    11
#     10   22     8     -7.1    0.922     8
#     11   19    24     -6.6    0.927     5
# Total extinctions: 0
# Generation time: 8.270 sec (9.110 average)
#
# Best individual in generation 49 meets fitness threshold - complexity: (11, 8)

# %%
draw_net(config, singol)

# %%
best_net = neat.nn.RecurrentNetwork.create(singol, config)
env = GSAIRD(report=True)
rew = []
obs = env.O

for i in range(500):
    rew.append( env.rew )
    actions = np.array( best_net.activate(obs) )
    env.step(actions)
    obs = env.O
    if env.status == 'Finished': break
env.close_rep()
        
S = np.array(env.Ss)
A = np.array(env.As)
R = np.array(env.Rs)
I = np.array(env.Is)
D = np.array(env.Ds)
ter = env.int_ter/env.N
        
fig, ax = plt.subplots(2, 2, figsize=(14,10) )
ax = ax.flatten()
ax[0].plot(S, color='blue', label= 'Susceptible')
ax[0].plot(A, color='orange', label= 'Asyntomatic')
ax[0].plot(I, color='red', label= 'Infectious')
ax[0].plot(R, color='gray', label= 'Recovered')
ax[0].plot(D, color='black', label= 'Dead')
ax[0].legend()

ax[1].axhline(ter, ls='--', color='black', label= 'Intensive terapy beds')
ax[1].plot(I*0.05, color='red', label='Hospitalized infected')
ax[1].legend()

ax[2].plot( env.evolution[1], color='red', label='Infection rate')
ax[2].plot( env.evolution[2], color='gray', label='Recovery rate')
ax[2].plot( env.evolution[3], color='black', label='Death rate')
ax[2].plot( env.evolution[4], color='green', label='Knowledge rate')
ax[2].legend()
#ax[2].set_xlim(0, 15)

ax[3].plot(rew, color='blue', label='Fitness')
ax[3].legend()

plt.show()

# %%
R0s = np.arange(1.5, 4.1, 0.1)
N = 100
success = np.zeros(len(R0s))
deads = np.zeros(len(R0s))
for i, r in enumerate(R0s):
    env = GSAIRD(report=True, R0=r)
    T=200
    dt=3
    for k in range(N):
        env.reset()
        obs = env.O
        for _ in range(T):
            actions = np.array( best_net.activate(obs) )
            env.step(actions)
            obs = env.O
            if env.status == 'Finished': break
        if max(env.Is)*0.05 < env.int_ter/env.N :
            success[i] += 1
        deads[i] += max(env.Ds)
deads /= N
success /= N

fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].plot(R0s, success, color='blue')
ax[0].set_xlabel('R0')
ax[0].set_ylabel('Fraction of success')
ax[1].plot(R0s, deads, color='red')
ax[1].set_xlabel('R0')
ax[1].set_ylabel('Fracions of deads')
plt.show()
